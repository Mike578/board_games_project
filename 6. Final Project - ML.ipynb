# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here's an example code snippet demonstrating these steps using one-hot encoding:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df_games is your DataFrame containing numerical and categorical variables

# One-hot encode categorical variables
encoded_categorical = pd.get_dummies(df_games[['theme', 'game_category', 'mechanics']])

# Concatenate encoded categorical variables with numerical variable (game rating)
concatenated_df = pd.concat([encoded_categorical, df_games['game_rating']], axis=1)

# Compute correlation matrix
correlation_matrix = concatenated_df.corr()

# Visualize correlation matrix as heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap between Game Rating and Categorical Variables')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# Assuming df_games is your DataFrame containing numerical and categorical variables

# Select numerical columns for normalization
numerical_columns = ['game_rating']  # Add other numerical columns if needed

# Normalize numerical columns using Min-Max scaling
scaler = MinMaxScaler()
df_games[numerical_columns] = scaler.fit_transform(df_games[numerical_columns])

# One-hot encode categorical variables
encoded_categorical = pd.get_dummies(df_games[['theme', 'game_category', 'mechanics', 'kickstarted']])

# Concatenate encoded categorical variables with normalized numerical columns
concatenated_df = pd.concat([encoded_categorical, df_games[numerical_columns]], axis=1)

# Compute correlation matrix
correlation_matrix = concatenated_df.corr()

# Visualize correlation matrix as heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap between Normalized Game Rating and Categorical Variables')
plt.show()

# %% [markdown]
# H0/H1 tests

# %% [markdown]
# Models like regression/ predict tree etc...

# %% [markdown]
# gfdrerg

# %%
# Get the full list of column names
column_names = df_games.columns

# Display the list of column names
print(column_names)

# %%
import pandas as pd

# Set display option to show all columns
pd.set_option('display.max_columns', None)

# Get the full list of column names and their corresponding data types
column_info = df_games.dtypes

# Convert Series to DataFrame for better display
column_info_df = column_info.to_frame().reset_index()
column_info_df.columns = ['Column Name', 'Data Type']

# Display the DataFrame
print(column_info_df)

# %%
from sklearn.preprocessing import MinMaxScaler

# Assuming df_games is your DataFrame containing numerical and categorical variables

# Select numerical columns for normalization
numerical_columns = ['game_weight', 'avg_rating','year_published','min_players', 'max_players', 
                     'com_age_rec','mfg_age_rec', 'language_ease','mfg_playtime', 'com_min_playtime', 
                     'com_max_playtime', 'num_user_ratings', 'num_alternates', 'num_expansions',
                     'is_reimplementation_binary','kickstarted_binary']  # Add other numerical columns if needed

# Normalize numerical columns using Min-Max scaling
scaler = MinMaxScaler()
df_games[numerical_columns] = scaler.fit_transform(df_games[numerical_columns])

# One-hot encode categorical variables
encoded_categorical = pd.get_dummies(df_games[['theme', 'category', 'mechanism', 'subcategory','artist', 'designer', 'publishing_company']])

# Concatenate encoded categorical variables with normalized numerical columns
concatenated_df = pd.concat([encoded_categorical, df_games[numerical_columns]], axis=1)

# Compute correlation matrix
correlation_matrix = concatenated_df.corr()

# Visualize correlation matrix as heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap between Normalized Game Rating and Categorical Variables')
plt.show()
